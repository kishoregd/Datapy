# %% [markdown]
# <h1>Predict Future Stock Price</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyodbc

# For Training, Testing and building a Model
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing,model_selection

from datetime import datetime

# %%
days_in_future_predict = 1

# %%
conn_str = ('server=WIN-EEL3AK31AJF;database=DatapyDB;TRUSTED_CONNECTION=yes')
#df = pd.read_csv('D:\\data\\XBIT.csv')

# %%
conn = pyodbc.connect(r'DRIVER={ODBC Driver 13 for SQL Server};' + conn_str)

# %%
#sql = "SELECT * FROM dbo.Stock where StockSym = 'XBIT' AND StockDt < '2019-12-06'"

sql =   "SELECT StockSym,StockDt,StockOpen,StockHigh,StockLow,StockClose,StockAdjClose,StockVol, \
        LAG(StockAdjClose,1,NULL) over (order by StockDt) StockAdjClose_DayMinus1, \
        LAG(StockVol,1,NULL) over (order by StockDt) StockVol_DayMinus1, \
        LAG(StockVol,2,NULL) over (order by StockDt) StockVol_DayMinus2, \
        LAG(StockVol,3,NULL) over (order by StockDt) StockVol_DayMinus3 \
        FROM dbo.Stock where StockSym = 'XBIT' AND StockDt < '2019-12-06'"

df = pd.read_sql(sql,conn)

# %%
df.head()
# Out:
#   StockSym     StockDt  StockOpen  StockHigh  StockLow  StockClose  \
# 0     XBIT  2018-01-02       3.99       4.06      3.98        3.98
# 1     XBIT  2018-01-03       4.00       4.24      3.96        4.10
# 2     XBIT  2018-01-04       4.17       4.22      4.07        4.12
# 3     XBIT  2018-01-05       4.12       4.33      4.07        4.20
# 4     XBIT  2018-01-08       4.18       4.21      4.02        4.13
#
#    StockAdjClose  StockVol  StockAdjClose_DayMinus1  StockVol_DayMinus1  \
# 0           3.98     45020                      NaN                 NaN
# 1           4.10    100960                     3.98             45020.0
# 2           4.12     39916                     4.10            100960.0
# 3           4.20     41798                     4.12             39916.0
# 4           4.13     35990                     4.20             41798.0
#
#    StockVol_DayMinus2  StockVol_DayMinus3
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2             45020.0                 NaN
# 3            100960.0             45020.0
# 4             39916.0            100960.0

# %%
df = df.drop(['StockSym'],axis=1)
df = df.drop(['StockDt'],axis=1)

# %%
df.head()
# Out:
#    StockOpen  StockHigh  StockLow  StockClose  StockAdjClose  StockVol  \
# 0       3.99       4.06      3.98        3.98           3.98     45020
# 1       4.00       4.24      3.96        4.10           4.10    100960
# 2       4.17       4.22      4.07        4.12           4.12     39916
# 3       4.12       4.33      4.07        4.20           4.20     41798
# 4       4.18       4.21      4.02        4.13           4.13     35990
#
#    StockAdjClose_DayMinus1  StockVol_DayMinus1  StockVol_DayMinus2  \
# 0                      NaN                 NaN                 NaN
# 1                     3.98             45020.0                 NaN
# 2                     4.10            100960.0             45020.0
# 3                     4.12             39916.0            100960.0
# 4                     4.20             41798.0             39916.0
#
#    StockVol_DayMinus3
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3             45020.0
# 4            100960.0

# %% [markdown]
# <h2>Add a derived column to the data frame</h2>

# %%
df['prediction'] = df[['StockAdjClose']].shift(-days_in_future_predict)

# %%
df.head()
# Out:
#    StockOpen  StockHigh  StockLow  StockClose  StockAdjClose  StockVol  \
# 0       3.99       4.06      3.98        3.98           3.98     45020
# 1       4.00       4.24      3.96        4.10           4.10    100960
# 2       4.17       4.22      4.07        4.12           4.12     39916
# 3       4.12       4.33      4.07        4.20           4.20     41798
# 4       4.18       4.21      4.02        4.13           4.13     35990
#
#    StockAdjClose_DayMinus1  StockVol_DayMinus1  StockVol_DayMinus2  \
# 0                      NaN                 NaN                 NaN
# 1                     3.98             45020.0                 NaN
# 2                     4.10            100960.0             45020.0
# 3                     4.12             39916.0            100960.0
# 4                     4.20             41798.0             39916.0
#
#    StockVol_DayMinus3  prediction
# 0                 NaN        4.10
# 1                 NaN        4.12
# 2                 NaN        4.20
# 3             45020.0        4.13
# 4            100960.0        4.01

# %%
df.tail(6)
# Out:
#      StockOpen  StockHigh  StockLow  StockClose  StockAdjClose  StockVol  \
# 480      11.71     12.025     11.51      11.815         11.815    184416
# 481      11.90     12.300     11.47      11.490         11.490    290397
# 482      11.65     12.230     10.80      11.000         11.000    303848
# 483      10.88     11.537     10.69      10.910         10.910    235103
# 484      11.10     11.680     11.10      11.330         11.330    300437
# 485      11.44     11.680     10.81      11.020         11.020    235989
#
#      StockAdjClose_DayMinus1  StockVol_DayMinus1  StockVol_DayMinus2  \
# 480                   11.540            369143.0            250747.0
# 481                   11.815            184416.0            369143.0
# 482                   11.490            290397.0            184416.0
# 483                   11.000            303848.0            290397.0
# 484                   10.910            235103.0            303848.0
# 485                   11.330            300437.0            235103.0
#
#      StockVol_DayMinus3  prediction
# 480            317945.0       11.49
# 481            250747.0       11.00
# 482            369143.0       10.91
# 483            184416.0       11.33
# 484            290397.0       11.02
# 485            303848.0         NaN

# %%
df.describe()
# Out:
#         StockOpen   StockHigh    StockLow  StockClose  StockAdjClose  \
# count  486.000000  486.000000  486.000000  486.000000     486.000000
# mean     6.448210    6.662525    6.238158    6.458004       6.458004
# std      2.587953    2.694394    2.484193    2.592050       2.592050
# min      2.550000    2.750000    2.130000    2.310000       2.310000
# 25%      4.300000    4.400000    4.200000    4.300000       4.300000
# 50%      5.045000    5.324000    4.925000    5.095000       5.095000
# 75%      8.695000    8.977500    8.397500    8.770000       8.770000
# max     14.810000   15.320000   13.490000   14.730000      14.730000
#
#            StockVol  StockAdjClose_DayMinus1  StockVol_DayMinus1  \
# count  4.860000e+02               485.000000        4.850000e+02
# mean   1.211522e+05                 6.448598        1.209155e+05
# std    1.777209e+05                 2.586410        1.778277e+05
# min    5.535000e+03                 2.310000        5.535000e+03
# 25%    3.841575e+04                 4.300000        3.835500e+04
# 50%    7.830600e+04                 5.080000        7.818600e+04
# 75%    1.446460e+05                 8.770000        1.436950e+05
# max    2.332409e+06                14.730000        2.332409e+06
#
#        StockVol_DayMinus2  StockVol_DayMinus3  prediction
# count        4.840000e+02        4.830000e+02  485.000000
# mean         1.205445e+05        1.203074e+05    6.463113
# std          1.778238e+05        1.779315e+05    2.592275
# min          5.535000e+03        5.535000e+03    2.310000
# 25%          3.833750e+04        3.832000e+04    4.300000
# 50%          7.775000e+04        7.731400e+04    5.110000
# 75%          1.432262e+05        1.430555e+05    8.770000
# max          2.332409e+06        2.332409e+06   14.730000

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#         StockOpen   StockHigh    StockLow  StockClose  StockAdjClose  \
# count  482.000000  482.000000  482.000000  482.000000     482.000000
# mean     6.452759    6.667608    6.242583    6.463423       6.463423
# std      2.581774    2.688695    2.479495    2.587587       2.587587
# min      2.550000    2.750000    2.130000    2.310000       2.310000
# 25%      4.300000    4.400000    4.202500    4.300000       4.300000
# 50%      5.060000    5.374000    4.930000    5.110000       5.110000
# 75%      8.695000    8.977500    8.397500    8.770000       8.770000
# max     14.810000   15.320000   13.490000   14.730000      14.730000
#
#            StockVol  StockAdjClose_DayMinus1  StockVol_DayMinus1  \
# count  4.820000e+02               482.000000        4.820000e+02
# mean   1.212824e+05                 6.448465        1.207419e+05
# std    1.783069e+05                 2.580225        1.781575e+05
# min    5.535000e+03                 2.310000        5.535000e+03
# 25%    3.830250e+04                 4.300000        3.830250e+04
# 50%    7.830600e+04                 5.095000        7.775000e+04
# 75%    1.446460e+05                 8.765000        1.435388e+05
# max    2.332409e+06                14.730000        2.332409e+06
#
#        StockVol_DayMinus2  StockVol_DayMinus3  prediction
# count        4.820000e+02        4.820000e+02  482.000000
# mean         1.204636e+05        1.199266e+05    6.477573
# std          1.780832e+05        1.779192e+05    2.593824
# min          5.535000e+03        5.535000e+03    2.310000
# 25%          3.830250e+04        3.830250e+04    4.302500
# 50%          7.775000e+04        7.716750e+04    5.120000
# 75%          1.430628e+05        1.429902e+05    8.792500
# max          2.332409e+06        2.332409e+06   14.730000

# %%
df.tail(3)
# Out:
#      StockOpen  StockHigh  StockLow  StockClose  StockAdjClose  StockVol  \
# 482      11.65     12.230     10.80       11.00          11.00    303848
# 483      10.88     11.537     10.69       10.91          10.91    235103
# 484      11.10     11.680     11.10       11.33          11.33    300437
#
#      StockAdjClose_DayMinus1  StockVol_DayMinus1  StockVol_DayMinus2  \
# 482                    11.49            290397.0            184416.0
# 483                    11.00            303848.0            290397.0
# 484                    10.91            235103.0            303848.0
#
#      StockVol_DayMinus3  prediction
# 482            369143.0       10.91
# 483            184416.0       11.33
# 484            290397.0       11.02

# %%
plt.scatter(df['StockAdjClose'],df['prediction'])

# %%
plt.plot(df['StockAdjClose'],color='red')
plt.plot(df['prediction'],color='green')

# %% [markdown]
# Read more on dataframe.drop
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
X = np.array(df.drop(['prediction'],1))

# %%
X
# Out:
# array([[4.12000e+00, 4.33000e+00, 4.07000e+00, ..., 3.99160e+04,
#         1.00960e+05, 4.50200e+04],
#        [4.18000e+00, 4.21000e+00, 4.02000e+00, ..., 4.17980e+04,
#         3.99160e+04, 1.00960e+05],
#        [4.12000e+00, 4.12000e+00, 3.96000e+00, ..., 3.59900e+04,
#         4.17980e+04, 3.99160e+04],
#        ...,
#        [1.16500e+01, 1.22300e+01, 1.08000e+01, ..., 2.90397e+05,
#         1.84416e+05, 3.69143e+05],
#        [1.08800e+01, 1.15370e+01, 1.06900e+01, ..., 3.03848e+05,
#         2.90397e+05, 1.84416e+05],
#        [1.11000e+01, 1.16800e+01, 1.11000e+01, ..., 2.35103e+05,
#         3.03848e+05, 2.90397e+05]])

# %%
print(type(X))
# Out:
# <class 'numpy.ndarray'>

# %%
len(X)
# Out:
# 482

# %%
df.describe()
# Out:
#         9.81 ,  9.38 ,  9.25 ,  9.4  ,  9.24 ,  9.08 ,  8.95 ,  9.19 ,
#         9.06 ,  8.92 ,  9.01 ,  9.06 ,  8.77 ,  9.08 ,  7.2  ,  7.54 ,
#         7.12 ,  7.11 ,  7.64 ,  7.8  ,  7.19 ,  7.1  ,  7.13 ,  6.99 ,
#         7.15 ,  7.28 ,  7.66 ,  7.4  ,  7.34 ,  7.54 ,  7.35 ,  7.5  ,
#         7.29 ,  7.45 ,  7.58 ,  7.55 ,  7.37 ,  8.04 ,  7.77 ,  7.74 ,
#         7.83 ,  7.76 ,  7.76 ,  7.29 ,  7.19 ,  7.16 ,  7.22 ,  7.19 ,
#         7.14 ,  7.22 ,  7.09 ,  6.86 ,  7.25 ,  7.06 ,  6.93 ,  6.96 ,
#         7.04 ,  7.28 ,  7.3  ,  6.91 ,  6.96 ,  7.07 ,  7.22 ,  7.09 ,
#         7.17 ,  7.4  ,  7.73 ,  7.76 ,  8.15 ,  8.62 ,  8.09 ,  8.23 ,
#         8.6  ,  8.22 ,  8.05 ,  7.99 ,  8.   ,  8.12 ,  8.35 ,  8.5  ,
#         8.48 ,  8.59 ,  8.81 ,  8.9  ,  9.01 ,  9.   ,  9.07 ,  9.7  ,
#         9.59 ,  9.62 ,  9.61 ,  9.62 ,  9.63 , 10.36 , 10.04 , 10.365,
#         9.865, 10.29 , 10.46 , 10.14 ,  9.28 ,  9.31 ,  8.95 ,  9.06 ,
#         8.99 ,  8.33 ,  8.58 ,  8.63 ,  8.54 ,  8.77 ,  8.83 ,  9.1  ,
#         9.4  ,  9.79 ,  9.3  ,  9.35 ,  9.9  ,  9.99 , 10.17 , 10.46 ,
#        10.99 , 10.87 , 11.28 , 10.6  , 10.47 , 10.36 , 10.52 , 11.09 ,
#        11.13 , 11.2  , 11.45 , 13.12 , 12.53 , 13.34 , 14.73 , 14.15 ,
#        13.52 , 12.85 , 12.59 , 11.54 , 11.815, 11.49 , 11.   , 10.91 ,
#        11.33 , 11.02 ])

# %%
len(Y)
# Out:
# 482

# %%
trainX,testX,trainY,testY = model_selection.train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# <h2>As part our Supervised Machine Leaning exercise, for training purpose we are using 80% of the records from our dataframe. </h2>

# %%
len(trainX)
# Out:
# 385

# %%
len(testX)
# Out:
# 97

# %%
len(trainY)
# Out:
# 385

# %% [markdown]
# <h2>Let's build a Statistical Model using SciKit</h2>

# %%
stockPricePredictModel = DecisionTreeRegressor() 
#stockPricePredictModel = LinearRegression() 

# Using fit method we are passing all the 388 records stored in both trainX and trainY variables.
# This is the training step in the model building process.

stockPricePredictModel.fit(trainX, trainY)

# With our model trained with 80% of data from the dataframe
# we want to test and see how model scores on the remaining 20% of the data
# Remember in real-world you may be dealing with Terabyte or Petabyte of data

# Score method: Passing both testX and testY variables (they both have 20% of the data)
# RSquared value is always between 0 and 1 and 1 being high accurancy of prediction
# I'm multiplying this factor with 100 to represent the value in terms of percentage 
rSquaredFactore = (stockPricePredictModel.score(testX,testY)) * 100

#prediction = (clf.predict(X_prediction))

# %%
print(rSquaredFactore)
# Out:
# 96.32897084459626

# %% [markdown]
# <h2>Let's see how our model predicts values for all the values in testX variable. Remeber testX has 20% of the data

# %% [markdown]
# Notice that I'm using predict method from the model.
# Tip: fit() to train, score() to get the R Squared Value and predict() to predict values

# %%
allTestPrediction = stockPricePredictModel.predict(testX)

# %% [markdown]
# <h2>Let's compare and see how our model performed on predictions

# %%
# Creating a temp DataFrame
dfTemp = pd.DataFrame({'Actual Value in Test (20% of the data)':testY, 'Model Predicted as ':allTestPrediction})

# %%
dfTemp
# Out:
#     Actual Value in Test (20% of the data)  Model Predicted as
# 0                                     4.90                 4.55
# 1                                     4.69                 4.76
# 2                                     4.42                 4.46
# 3                                     6.07                 6.26
# 4                                     2.31                 2.70
# ..                                     ...                  ...
# 92                                    8.81                 8.51
# 93                                    4.23                 4.30
# 94                                   11.13                11.20
# 95                                    3.31                 3.45
# 96                                    7.77                 9.34
#
# [97 rows x 2 columns]

# %%
plt.figure(figsize=(16,9))
plt.plot(testY,color="blue")
plt.plot(allTestPrediction,color="red")

# %%
#sql = "SELECT TOP 1 * FROM dbo.Stock where StockSym = 'XBIT' AND StockDt < '2019-12-06' ORDER BY StockDt DESC"

sql =  "SELECT TOP 1 StockSym,StockDt,StockOpen,StockHigh,StockLow,StockClose,StockAdjClose,StockVol, \
       LAG(StockAdjClose,1,NULL) over (order by StockDt) StockAdjClose_DayMinus1, \
       LAG(StockVol,1,NULL) over (order by StockDt) StockVol_DayMinus1, \
       LAG(StockVol,2,NULL) over (order by StockDt) StockVol_DayMinus2, \
       LAG(StockVol,3,NULL) over (order by StockDt) StockVol_DayMinus3 \
       FROM dbo.Stock where StockSym = 'XBIT' AND StockDt < '2019-12-06' \
       ORDER BY StockDt DESC"

dfLastRecordedTrade = pd.read_sql(sql,conn)

# %%
dfLastRecordedTrade.head()
# Out:
#   StockSym     StockDt  StockOpen  StockHigh  StockLow  StockClose  \
# 0     XBIT  2019-12-05      11.44      11.68     10.81       11.02
#
#    StockAdjClose  StockVol  StockAdjClose_DayMinus1  StockVol_DayMinus1  \
# 0          11.02    235989                    11.33              300437
#
#    StockVol_DayMinus2  StockVol_DayMinus3
# 0              235103              303848

# %%
dfLastRecordedTrade = dfLastRecordedTrade.drop(['StockSym'],axis=1)
dfLastRecordedTrade = dfLastRecordedTrade.drop(['StockDt'],axis=1)

# %%
dfLastRecordedTrade.head()
# Out:
#    StockOpen  StockHigh  StockLow  StockClose  StockAdjClose  StockVol  \
# 0      11.44      11.68     10.81       11.02          11.02    235989
#
#    StockAdjClose_DayMinus1  StockVol_DayMinus1  StockVol_DayMinus2  \
# 0                    11.33              300437              235103
#
#    StockVol_DayMinus3
# 0              303848

# %%
inputX = np.array(dfLastRecordedTrade)

# %%
inputX
# Out:
# array([[1.14400e+01, 1.16800e+01, 1.08100e+01, 1.10200e+01, 1.10200e+01,
#         2.35989e+05, 1.13300e+01, 3.00437e+05, 2.35103e+05, 3.03848e+05]])

# %%
futureStockPrice = stockPricePredictModel.predict(inputX)

# %%
print(futureStockPrice)
# Out:
# [11.33]
